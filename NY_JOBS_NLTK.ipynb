# %% [markdown]
# <a href="https://colab.research.google.com/github/Yella-reddy718/AIML/blob/master/NY_JOBS_NLTK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code for Step 1
# !pip install -U -q PyDrive
 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
listed = drive.ListFile({'q': "title contains 'nyc_job.zip' and '11ZDHYT6d9UtFPIRByM3u6ZYBNea5gGDC' in parents"}).GetList()

for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))

# %%
train_downloaded = drive.CreateFile({'id': '1G2h2yFvG5vPvjwMuFpiUZwbMn11HxcMZ'})
train_downloaded.GetContentFile('nyc_job.zip')

# %%
import zipfile
import pandas as pd
import numpy as np
import re
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

from wordcloud import WordCloud,STOPWORDS
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
with zipfile.ZipFile("nyc_job.zip") as zip_ref:
  zip_ref.extractall()

# %%
#Define the colors
p = "YlGnBu"
p2 = "YlGn"
p3 = "Greys"

# %%
jobs = pd.read_csv("nyc-jobs.csv")
jobs.head(3)
# Out:
#    Job ID  ...             Process Date
# 0   87990  ...  2019-06-11T00:00:00.000
# 1   97899  ...  2019-06-11T00:00:00.000
# 2  132292  ...  2019-06-11T00:00:00.000
#
# [3 rows x 28 columns]

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3159 entries, 0 to 3158
# Data columns (total 28 columns):
# Job ID                           3159 non-null int64
# Agency                           3159 non-null object
# Posting Type                     3159 non-null object
# # Of Positions                   3159 non-null int64
# Business Title                   3159 non-null object
# Civil Service Title              3159 non-null object
# Title Code No                    3159 non-null object
# Level                            3159 non-null object
# Job Category                     3157 non-null object
# Full-Time/Part-Time indicator    2926 non-null object
# Salary Range From                3159 non-null float64
# Salary Range To                  3159 non-null float64
# Salary Frequency                 3159 non-null object
# Work Location                    3159 non-null object
# Division/Work Unit               3159 non-null object
# Job Description                  3159 non-null object
# Minimum Qual Requirements        3146 non-null object
# Preferred Skills                 2770 non-null object
# Additional Information           2001 non-null object
# To Apply                         3158 non-null object
# Hours/Shift                      1012 non-null object
# Work Location 1                  1424 non-null object
# Recruitment Contact              0 non-null float64
# Residency Requirement            3159 non-null object
# Posting Date                     3159 non-null object
# Post Until                       971 non-null object
# Posting Updated                  3159 non-null object
# Process Date                     3159 non-null object
# dtypes: float64(3), int64(2), object(23)
# memory usage: 691.2+ KB

# %% [markdown]
# Data cleaning & Feature engineering

# %%
def plot_wordcloud(text):
    wordcloud = WordCloud(background_color='white',
                     width=1024, height=720).generate(text)
    plt.clf()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.show()
def parse_categories(x):
    l = x.replace('&', ',').split(',')
    print(l)
    l = [x.strip().rstrip(',') for x in l]
    print(l)
    key_categories.extend(l)

def parse_keywords(x, l):
    x = x.lower()
    tokens = nltk.word_tokenize(x)
    stop_words = set(stopwords.words('english'))
    token_l = [w for w in tokens if not w in stop_words and w.isalpha()]
    l.extend(token_l)
    
def preferred_skills(x):
    kwl = []
    jobs[jobs.job_category==x].preferred_skills.dropna().apply(parse_keywords, l=kwl)
    kwl = pd.Series(kwl)
    return kwl.value_counts()[:20]

# %%
jobs.columns
# Out:
# Index(['Job ID', 'Agency', 'Posting Type', '# Of Positions', 'Business Title',
#        'Civil Service Title', 'Title Code No', 'Level', 'Job Category',
#        'Full-Time/Part-Time indicator', 'Salary Range From', 'Salary Range To',
#        'Salary Frequency', 'Work Location', 'Division/Work Unit',
#        'Job Description', 'Minimum Qual Requirements', 'Preferred Skills',
#        'Additional Information', 'To Apply', 'Hours/Shift', 'Work Location 1',
#        'Recruitment Contact', 'Residency Requirement', 'Posting Date',
#        'Post Until', 'Posting Updated', 'Process Date'],
#       dtype='object')

# %%
#Drop the Recuitment Contact and Post Until Columns
jobs.drop(['Recruitment Contact', 'Post Until'], axis=1, inplace=True)

# %%
#Define the Column names
jobs.columns = ['id', 'agency', 'posting_type', 'number_of_positions', 'business_title', 'civil_service_title', 'title_code_number', 'level', 'job_category', 'full-time/part-time', 'salary_range_low', 'salary_range_high', 'salary_frequency', 'work_location', 'work_unit', 'job_description', 'minimum_requirements', 'preferred_skills', 'additional_info', 'to_apply', 'shift', 'work_location_1', 'residency_requirement', 'posting_date', 'posting_updated', 'process_date' ]

# %%
#Verify the column names
jobs.columns
# Out:
# Index(['id', 'agency', 'posting_type', 'number_of_positions', 'business_title',
#        'civil_service_title', 'title_code_number', 'level', 'job_category',
#        'full-time/part-time', 'salary_range_low', 'salary_range_high',
#        'salary_frequency', 'work_location', 'work_unit', 'job_description',
#        'minimum_requirements', 'preferred_skills', 'additional_info',
#        'to_apply', 'shift', 'work_location_1', 'residency_requirement',
#        'posting_date', 'posting_updated', 'process_date'],
#       dtype='object')

# %%
jobs['job_category'].unique()
# Out:
# array([nan, 'Maintenance & Operations',
#        'Finance, Accounting, & Procurement',
#        'Health Public Safety, Inspections, & Enforcement',
#        'Engineering, Architecture, & Planning',
#        'Clerical & Administrative Support',
#        'Information Technology & Telecommunications',
#        'Finance, Accounting, & Procurement Information Technology & Telecommunications',
#        'Community & Business Services',
#        'Clerical & Administrative Support Legal',
#        'Clerical & Administrative Support Community & Business Services',
#        'Social Services',
#        'Engineering, Architecture, & Planning Maintenance & Operations',
#        'Health', 'Clerical & Administrative Support Policy & Analysis',
#        'Community & Business Services Social Services',
#        'Public Safety, Inspections, & Enforcement', 'Legal',
#        'Policy & Analysis Social Services',
#        'Information Technology & Telecommunications Policy & Analysis Social Services',
#        'Legal Policy & Analysis',
#        'Finance, Accounting, & Procurement Policy & Analysis',
#        'Administration & Human Resources Legal Affairs',
#        'Finance, Accounting, & Procurement Policy, Research & Analysis',
#        'Building Operations & Maintenance',
#        'Technology, Data & Innovation',
#        'Engineering, Architecture, & Planning Building Operations & Maintenance',
#        'Policy, Research & Analysis',
#        'Communications & Intergovernmental Affairs',
#        'Administration & Human Resources',
#        'Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Engineering, Architecture, & Planning Technology, Data & Innovation',
#        'Legal Affairs Policy, Research & Analysis',
#        'Engineering, Architecture, & Planning Policy, Research & Analysis',
#        'Administration & Human Resources Policy, Research & Analysis',
#        'Administration & Human Resources Public Safety, Inspections, & Enforcement',
#        'Engineering, Architecture, & Planning Finance, Accounting, & Procurement Building Operations & Maintenance Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Finance, Accounting, & Procurement',
#        'Legal Affairs',
#        'Administration & Human Resources Health Public Safety, Inspections, & Enforcement',
#        'Building Operations & Maintenance Public Safety, Inspections, & Enforcement',
#        'Technology, Data & Innovation Policy, Research & Analysis',
#        'Policy, Research & Analysis Public Safety, Inspections, & Enforcement Social Services',
#        'Constituent Services & Community Programs',
#        'Engineering, Architecture, & Planning Public Safety, Inspections, & Enforcement',
#        'Health Building Operations & Maintenance Public Safety, Inspections, & Enforcement',
#        'Finance, Accounting, & Procurement Social Services',
#        'Administration & Human Resources Technology, Data & Innovation',
#        'Constituent Services & Community Programs Communications & Intergovernmental Affairs Engineering, Architecture, & Planning Policy, Research & Analysis',
#        'Health Policy, Research & Analysis',
#        'Administration & Human Resources Communications & Intergovernmental Affairs',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Legal Affairs',
#        'Building Operations & Maintenance Public Safety, Inspections, & Enforcement Social Services',
#        'Legal Affairs Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Constituent Services & Community Programs Policy, Research & Analysis',
#        'Engineering, Architecture, & Planning Finance, Accounting, & Procurement',
#        'Constituent Services & Community Programs Policy, Research & Analysis',
#        'Administration & Human Resources Social Services',
#        'Finance, Accounting, & Procurement Legal Affairs Policy, Research & Analysis',
#        'Communications & Intergovernmental Affairs Policy, Research & Analysis',
#        'Legal Affairs Policy, Research & Analysis Public Safety, Inspections, & Enforcement Social Services',
#        'Constituent Services & Community Programs Engineering, Architecture, & Planning',
#        'Administration & Human Resources Constituent Services & Community Programs Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Health Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Constituent Services & Community Programs Communications & Intergovernmental Affairs Policy, Research & Analysis',
#        'Constituent Services & Community Programs Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Health Building Operations & Maintenance',
#        'Communications & Intergovernmental Affairs Legal Affairs Policy, Research & Analysis',
#        'Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs Building Operations & Maintenance Public Safety, Inspections, & Enforcement Social Services',
#        'Constituent Services & Community Programs Communications & Intergovernmental Affairs Health Social Services',
#        'Administration & Human Resources Policy, Research & Analysis Social Services',
#        'Administration & Human Resources Constituent Services & Community Programs Finance, Accounting, & Procurement Policy, Research & Analysis',
#        'Communications & Intergovernmental Affairs Technology, Data & Innovation',
#        'Constituent Services & Community Programs Social Services',
#        'Constituent Services & Community Programs Communications & Intergovernmental Affairs',
#        'Health Social Services',
#        'Constituent Services & Community Programs Communications & Intergovernmental Affairs Finance, Accounting, & Procurement Policy, Research & Analysis',
#        'Policy, Research & Analysis Social Services',
#        'Engineering, Architecture, & Planning Health',
#        'Engineering, Architecture, & Planning Building Operations & Maintenance Public Safety, Inspections, & Enforcement',
#        'Constituent Services & Community Programs Health Policy, Research & Analysis Social Services',
#        'Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs',
#        'Administration & Human Resources Constituent Services & Community Programs',
#        'Engineering, Architecture, & Planning Technology, Data & Innovation Policy, Research & Analysis',
#        'Communications & Intergovernmental Affairs Health Technology, Data & Innovation',
#        'Constituent Services & Community Programs Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Technology, Data & Innovation',
#        'Finance, Accounting, & Procurement Building Operations & Maintenance',
#        'Constituent Services & Community Programs Engineering, Architecture, & Planning Legal Affairs',
#        'Health Technology, Data & Innovation',
#        'Communications & Intergovernmental Affairs Public Safety, Inspections, & Enforcement',
#        'Legal Affairs Public Safety, Inspections, & Enforcement',
#        'Health Legal Affairs',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Finance, Accounting, & Procurement Legal Affairs Public Safety, Inspections, & Enforcement',
#        'Technology, Data & Innovation Social Services',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Public Safety, Inspections, & Enforcement',
#        'Public Safety, Inspections, & Enforcement Social Services',
#        'Technology, Data & Innovation Public Safety, Inspections, & Enforcement',
#        'Constituent Services & Community Programs Building Operations & Maintenance',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Engineering, Architecture, & Planning Finance, Accounting, & Procurement Health Technology, Data & Innovation Legal Affairs Building Operations & Maintenance Policy, Research & Analysis',
#        'Constituent Services & Community Programs Health Social Services',
#        'Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Engineering, Architecture, & Planning Policy, Research & Analysis',
#        'Constituent Services & Community Programs Legal Affairs Policy, Research & Analysis Social Services',
#        'Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs Health Social Services',
#        'Constituent Services & Community Programs Legal Affairs',
#        'Administration & Human Resources Finance, Accounting, & Procurement Legal Affairs Building Operations & Maintenance Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Health Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Building Operations & Maintenance',
#        'Finance, Accounting, & Procurement Legal Affairs',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Engineering, Architecture, & Planning Policy, Research & Analysis',
#        'Administration & Human Resources Technology, Data & Innovation Building Operations & Maintenance',
#        'Administration & Human Resources Constituent Services & Community Programs Social Services',
#        'Finance, Accounting, & Procurement Health Policy, Research & Analysis Social Services',
#        'Administration & Human Resources Finance, Accounting, & Procurement Technology, Data & Innovation',
#        'Finance, Accounting, & Procurement Public Safety, Inspections, & Enforcement',
#        'Administration & Human Resources Finance, Accounting, & Procurement Social Services',
#        'Administration & Human Resources Finance, Accounting, & Procurement Public Safety, Inspections, & Enforcement Social Services',
#        'Engineering, Architecture, & Planning Technology, Data & Innovation Public Safety, Inspections, & Enforcement',
#        'Constituent Services & Community Programs Engineering, Architecture, & Planning Social Services',
#        'Constituent Services & Community Programs Legal Affairs Policy, Research & Analysis',
#        'Administration & Human Resources Finance, Accounting, & Procurement Technology, Data & Innovation Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Finance, Accounting, & Procurement Technology, Data & Innovation',
#        'Administration & Human Resources Constituent Services & Community Programs Technology, Data & Innovation Social Services',
#        'Administration & Human Resources Finance, Accounting, & Procurement Policy, Research & Analysis',
#        'Administration & Human Resources Constituent Services & Community Programs Communications & Intergovernmental Affairs Social Services',
#        'Administration & Human Resources Communications & Intergovernmental Affairs Policy, Research & Analysis',
#        'Administration & Human Resources Health Technology, Data & Innovation Building Operations & Maintenance Social Services',
#        'Administration & Human Resources Finance, Accounting, & Procurement Building Operations & Maintenance',
#        'Constituent Services & Community Programs Communications & Intergovernmental Affairs Finance, Accounting, & Procurement Policy, Research & Analysis Social Services',
#        'Constituent Services & Community Programs Engineering, Architecture, & Planning Policy, Research & Analysis Public Safety, Inspections, & Enforcement',
#        'Communications & Intergovernmental Affairs Finance, Accounting, & Procurement Legal Affairs Policy, Research & Analysis'],
#       dtype=object)

# %%
jobs.job_category.value_counts()
# Out:
# Engineering, Architecture, & Planning                                                                                      537
# Technology, Data & Innovation                                                                                              320
# Public Safety, Inspections, & Enforcement                                                                                  236
# Health                                                                                                                     216
# Legal Affairs                                                                                                              182
#                                                                                                                           ...
# Building Operations & Maintenance Public Safety, Inspections, & Enforcement Social Services                                  1
# Administration & Human Resources Technology, Data & Innovation Building Operations & Maintenance                             1
# Finance, Accounting, & Procurement Information Technology & Telecommunications                                               1
# Administration & Human Resources Health Technology, Data & Innovation Building Operations & Maintenance Social Services      1
# Health Building Operations & Maintenance Public Safety, Inspections, & Enforcement                                           1
# Name: job_category, Length: 131, dtype: int64

# %%
key_categories = []
jobs.job_category.dropna().apply(parse_categories)
key_categories = pd.Series(key_categories)
key_categories = key_categories[key_categories!='']
print(key_categories)
popular_categories = key_categories.value_counts().iloc[:25]
popular_categories
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Technology', 'Data', 'Innovation']
# ['Administration ', ' Human Resources Constituent Services ', ' Community Programs Policy', ' Research ', ' Analysis']
# ['Administration', 'Human Resources Constituent Services', 'Community Programs Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Health Policy', ' Research ', ' Analysis']
# ['Health Policy', 'Research', 'Analysis']
# ['Health Policy', ' Research ', ' Analysis']
# ['Health Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Health Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Health Public Safety', 'Inspections', '', 'Enforcement']
# ['Health Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Health Public Safety', 'Inspections', '', 'Enforcement']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Health']
# ['Health']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Health']
# ['Health']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Building Operations ', ' Maintenance Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Building Operations', 'Maintenance Public Safety', 'Inspections', '', 'Enforcement']
# ['Building Operations ', ' Maintenance Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Building Operations', 'Maintenance Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Constituent Services ', ' Community Programs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Health Policy', ' Research ', ' Analysis']
# ['Health Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Administration ', ' Human Resources Social Services']
# ['Administration', 'Human Resources Social Services']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Social Services']
# ['Social Services']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Health Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Health Public Safety', 'Inspections', '', 'Enforcement']
# ['Health Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Health Public Safety', 'Inspections', '', 'Enforcement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Finance', ' Accounting', ' ', ' Procurement Legal Affairs Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Legal Affairs Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Legal Affairs Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Legal Affairs Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Health Policy', ' Research ', ' Analysis']
# ['Health Policy', 'Research', 'Analysis']
# ['Health Policy', ' Research ', ' Analysis']
# ['Health Policy', 'Research', 'Analysis']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Administration ', ' Human Resources Social Services']
# ['Administration', 'Human Resources Social Services']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Legal Affairs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement Social Services']
# ['Legal Affairs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement Social Services']
# ['Legal Affairs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement Social Services']
# ['Legal Affairs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement Social Services']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Constituent Services ', ' Community Programs Engineering', ' Architecture', ' ', ' Planning']
# ['Constituent Services', 'Community Programs Engineering', 'Architecture', '', 'Planning']
# ['Constituent Services ', ' Community Programs Engineering', ' Architecture', ' ', ' Planning']
# ['Constituent Services', 'Community Programs Engineering', 'Architecture', '', 'Planning']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Administration ', ' Human Resources Finance', ' Accounting', ' ', ' Procurement']
# ['Administration', 'Human Resources Finance', 'Accounting', '', 'Procurement']
# ['Administration ', ' Human Resources Finance', ' Accounting', ' ', ' Procurement']
# ['Administration', 'Human Resources Finance', 'Accounting', '', 'Procurement']
# ['Legal Affairs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Legal Affairs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Legal Affairs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Legal Affairs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Administration ', ' Human Resources Constituent Services ', ' Community Programs Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Administration', 'Human Resources Constituent Services', 'Community Programs Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources Constituent Services ', ' Community Programs Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Administration', 'Human Resources Constituent Services', 'Community Programs Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources Health Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Administration', 'Human Resources Health Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources Health Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Administration', 'Human Resources Health Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Social Services']
# ['Social Services']
# ['Health Policy', ' Research ', ' Analysis']
# ['Health Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis']
# ['Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning Technology', ' Data ', ' Innovation']
# ['Engineering', 'Architecture', '', 'Planning Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Constituent Services ', ' Community Programs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Constituent Services', 'Community Programs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Constituent Services ', ' Community Programs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Constituent Services', 'Community Programs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Health Building Operations ', ' Maintenance']
# ['Health Building Operations', 'Maintenance']
# ['Health Building Operations ', ' Maintenance']
# ['Health Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Communications ', ' Intergovernmental Affairs Legal Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Legal Affairs Policy', 'Research', 'Analysis']
# ['Communications ', ' Intergovernmental Affairs Legal Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Legal Affairs Policy', 'Research', 'Analysis']
# ['Administration ', ' Human Resources Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Building Operations ', ' Maintenance Public Safety', ' Inspections', ' ', ' Enforcement Social Services']
# ['Administration', 'Human Resources Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Building Operations', 'Maintenance Public Safety', 'Inspections', '', 'Enforcement Social Services']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Health Social Services']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Health Social Services']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Health Social Services']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Health Social Services']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Legal Affairs Policy', ' Research ', ' Analysis']
# ['Legal Affairs Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Engineering', ' Architecture', ' ', ' Planning Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Engineering', 'Architecture', '', 'Planning Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Social Services']
# ['Social Services']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Administration ', ' Human Resources Policy', ' Research ', ' Analysis']
# ['Administration', 'Human Resources Policy', 'Research', 'Analysis']
# ['Administration ', ' Human Resources Policy', ' Research ', ' Analysis']
# ['Administration', 'Human Resources Policy', 'Research', 'Analysis']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Administration ', ' Human Resources Policy', ' Research ', ' Analysis Social Services']
# ['Administration', 'Human Resources Policy', 'Research', 'Analysis Social Services']
# ['Administration ', ' Human Resources Policy', ' Research ', ' Analysis Social Services']
# ['Administration', 'Human Resources Policy', 'Research', 'Analysis Social Services']
# ['Technology', ' Data ', ' Innovation Policy', ' Research ', ' Analysis']
# ['Technology', 'Data', 'Innovation Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation Policy', ' Research ', ' Analysis']
# ['Technology', 'Data', 'Innovation Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation Policy', ' Research ', ' Analysis']
# ['Technology', 'Data', 'Innovation Policy', 'Research', 'Analysis']
# ['Technology', ' Data ', ' Innovation Policy', ' Research ', ' Analysis']
# ['Technology', 'Data', 'Innovation Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Engineering', ' Architecture', ' ', ' Planning Finance', ' Accounting', ' ', ' Procurement']
# ['Engineering', 'Architecture', '', 'Planning Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Legal Affairs Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Legal Affairs Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Legal Affairs Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Legal Affairs Policy', 'Research', 'Analysis']
# ['Social Services']
# ['Social Services']
# ...
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Administration ', ' Human Resources Policy', ' Research ', ' Analysis']
# ['Administration', 'Human Resources Policy', 'Research', 'Analysis']
# ['Administration ', ' Human Resources Policy', ' Research ', ' Analysis']
# ['Administration', 'Human Resources Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Social Services']
# ['Social Services']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Administration ', ' Human Resources Social Services']
# ['Administration', 'Human Resources Social Services']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Constituent Services ', ' Community Programs Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Constituent Services', 'Community Programs Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources Social Services']
# ['Administration', 'Human Resources Social Services']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Health']
# ['Health']
# ['Constituent Services ', ' Community Programs Engineering', ' Architecture', ' ', ' Planning Policy', ' Research ', ' Analysis Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Constituent Services', 'Community Programs Engineering', 'Architecture', '', 'Planning Policy', 'Research', 'Analysis Public Safety', 'Inspections', '', 'Enforcement']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Technology', ' Data ', ' Innovation']
# ['Technology', 'Data', 'Innovation']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Finance', ' Accounting', ' ', ' Procurement']
# ['Finance', 'Accounting', '', 'Procurement']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Public Safety', 'Inspections', '', 'Enforcement']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Social Services']
# ['Social Services']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs Building Operations ', ' Maintenance']
# ['Constituent Services', 'Community Programs Building Operations', 'Maintenance']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Constituent Services ', ' Community Programs Communications ', ' Intergovernmental Affairs Policy', ' Research ', ' Analysis']
# ['Constituent Services', 'Community Programs Communications', 'Intergovernmental Affairs Policy', 'Research', 'Analysis']
# ['Communications ', ' Intergovernmental Affairs Finance', ' Accounting', ' ', ' Procurement Legal Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Finance', 'Accounting', '', 'Procurement Legal Affairs Policy', 'Research', 'Analysis']
# ['Communications ', ' Intergovernmental Affairs Finance', ' Accounting', ' ', ' Procurement Legal Affairs Policy', ' Research ', ' Analysis']
# ['Communications', 'Intergovernmental Affairs Finance', 'Accounting', '', 'Procurement Legal Affairs Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Finance', ' Accounting', ' ', ' Procurement Policy', ' Research ', ' Analysis']
# ['Finance', 'Accounting', '', 'Procurement Policy', 'Research', 'Analysis']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Communications ', ' Intergovernmental Affairs Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Communications', 'Intergovernmental Affairs Public Safety', 'Inspections', '', 'Enforcement']
# ['Communications ', ' Intergovernmental Affairs Public Safety', ' Inspections', ' ', ' Enforcement']
# ['Communications', 'Intergovernmental Affairs Public Safety', 'Inspections', '', 'Enforcement']
# ['Constituent Services ', ' Community Programs Social Services']
# ['Constituent Services', 'Community Programs Social Services']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Administration ', ' Human Resources']
# ['Administration', 'Human Resources']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Social Services']
# ['Social Services']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Policy', ' Research ', ' Analysis']
# ['Policy', 'Research', 'Analysis']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Legal Affairs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Constituent Services ', ' Community Programs']
# ['Constituent Services', 'Community Programs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Communications ', ' Intergovernmental Affairs']
# ['Communications', 'Intergovernmental Affairs']
# ['Constituent Services ', ' Community Programs Social Services']
# ['Constituent Services', 'Community Programs Social Services']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Building Operations ', ' Maintenance']
# ['Building Operations', 'Maintenance']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# ['Engineering', ' Architecture', ' ', ' Planning']
# ['Engineering', 'Architecture', '', 'Planning']
# 0         Maintenance
# 1          Operations
# 2         Maintenance
# 3          Operations
# 4         Maintenance
#              ...
# 10540    Architecture
# 10542        Planning
# 10543     Engineering
# 10544    Architecture
# 10546        Planning
# Length: 8979, dtype: object
# Architecture              771
# Engineering               750
# Planning                  540
# Inspections               502
# Enforcement               492
# Research                  432
# Data                      416
# Innovation                383
# Analysis                  377
# Technology                340
# Accounting                295
# Administration            269
# Constituent Services      240
# Public Safety             239
# Finance                   239
# Health                    216
# Maintenance               214
# Building Operations       188
# Procurement               184
# Legal Affairs             182
# Community Programs        161
# Policy                    141
# Human Resources           134
# Planning Public Safety     98
# Communications             70
# dtype: int64

# %%
jobs['full-time/part-time'].value_counts()
# Out:
# F    2757
# P     169
# Name: full-time/part-time, dtype: int64

# %%
sns.countplot(x='full-time/part-time', data=jobs, palette=p)

# %%
jobs.salary_frequency.value_counts()
# Out:
# Annual    2862
# Hourly     263
# Daily       34
# Name: salary_frequency, dtype: int64

# %%
sns.countplot(x='salary_frequency',data=jobs,palette = p2)

# %% [markdown]
# Demand Job Categories

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=key_categories, order=popular_categories.index, palette=p)

# %%
print(popular_categories.index.tolist())
# Out:
# ['Architecture', 'Engineering', 'Planning', 'Inspections', 'Enforcement', 'Research', 'Data', 'Innovation', 'Analysis', 'Technology', 'Accounting', 'Administration', 'Constituent Services', 'Public Safety', 'Finance', 'Health', 'Maintenance', 'Building Operations', 'Procurement', 'Legal Affairs', 'Community Programs', 'Policy', 'Human Resources', 'Planning Public Safety', 'Communications']

# %%
plt.figure(figsize=(10,8))
plot_wordcloud(' '.join(popular_categories.index.tolist()))

# %% [markdown]
# Popular Job Titles

# %%
plt.figure(figsize=(10,10))
titles_freq = jobs.civil_service_title.value_counts()
popular_titles = titles_freq.iloc[:25]
sns.countplot(y="civil_service_title", data=jobs, order=popular_titles.index, palette=p)

# %%
plt.figure(figsize=(10,8))
plot_wordcloud(' '.join(popular_titles.index.tolist()))

# %%
Least_popular = titles_freq.iloc[-10:]
sns.countplot(y="civil_service_title", data=jobs, order=Least_popular.index, palette=p3)

# %% [markdown]
# JObs With Highest Low Salary Range

# %%
salary_table = jobs[['civil_service_title', 'salary_range_low', 'salary_range_high']]
jobs_highest_low_range = pd.DataFrame(salary_table.groupby(['civil_service_title'])['salary_range_low'].mean().nlargest(10)).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(y='civil_service_title', x='salary_range_low', data=jobs_highest_low_range, palette=p)

# %% [markdown]
# JOb with Highest High Salary range

# %%
jobs_highest_high_range = pd.DataFrame(salary_table.groupby(['civil_service_title'])['salary_range_high'].mean().nlargest(10)).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(y='civil_service_title', x='salary_range_high', data=jobs_highest_high_range, palette=p)

# %% [markdown]
# Highest paying Jobs on Hourly Basis

# %%
hourly_jobs = jobs[jobs.salary_frequency == 'Hourly']
jobs_highest_high_range_hourly = pd.DataFrame(hourly_jobs.groupby(['civil_service_title'])['salary_range_high'].mean().nlargest(10)).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(y='civil_service_title', x='salary_range_high', data=jobs_highest_high_range_hourly, palette=p2)

# %%
plt.figure(figsize=(10,8))
plot_wordcloud(' '.join(jobs_highest_high_range_hourly['civil_service_title'].tolist()))

# %% [markdown]
# Hourly Job Salary DIstribution

# %%
sns.distplot(hourly_jobs.salary_range_high)

# %% [markdown]
# Popular Work Units

# %%
popular_divisions = jobs.work_unit.value_counts().iloc[:10]
sns.countplot(y='work_unit', data=jobs, order=popular_divisions.index, palette='PuBuGn')

# %%
job_description_keywords = []
jobs.job_description.apply(parse_keywords, l=job_description_keywords)
plt.figure(figsize=(10, 8))
counter = Counter(job_description_keywords)
common = [x[0] for x in counter.most_common(40)]
plot_wordcloud(' '.join(common))

# %% [markdown]
# Most Preferred Skill on Job Category

# %%
opular_categories = jobs.job_category.value_counts()[:5]
popular_categories
# Out:
# Architecture              771
# Engineering               750
# Planning                  540
# Inspections               502
# Enforcement               492
# Research                  432
# Data                      416
# Innovation                383
# Analysis                  377
# Technology                340
# Accounting                295
# Administration            269
# Constituent Services      240
# Public Safety             239
# Finance                   239
# Health                    216
# Maintenance               214
# Building Operations       188
# Procurement               184
# Legal Affairs             182
# Community Programs        161
# Policy                    141
# Human Resources           134
# Planning Public Safety     98
# Communications             70
# dtype: int64

# %% [markdown]
# Minimum Qualification

# %%
qualification_keywords = []
jobs.minimum_requirements.dropna().apply(parse_keywords, l=qualification_keywords)
plt.figure(figsize=(10, 8))
counter = Counter(qualification_keywords)
common = [x[0] for x in counter.most_common(40)]
plot_wordcloud(' '.join(common))
